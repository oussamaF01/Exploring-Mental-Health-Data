# %% [markdown]
# # Get the data

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-175b06b4-8e82-48cd-99e9-c11f74af98b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-175b06b4-8e82-48cd-99e9-c11f74af98b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle competitions download -c playground-series-s4e11
# Out:
# playground-series-s4e11.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip playground-series-s4e11.zip
# Out:
# Archive:  playground-series-s4e11.zip
# replace sample_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# # Import Module

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')

# %% [markdown]
# # Explore the data

# %%
data_train.head(5)
# Out:
#    id      Name  Gender   Age           City Working Professional or Student  \
# 0   0  Aaradhya  Female  49.0       Ludhiana            Working Professional
# 1   1     Vivan    Male  26.0       Varanasi            Working Professional
# 2   2    Yuvraj    Male  33.0  Visakhapatnam                         Student
# 3   3    Yuvraj    Male  22.0         Mumbai            Working Professional
# 4   4      Rhea  Female  30.0         Kanpur            Working Professional
#
#          Profession  Academic Pressure  Work Pressure  CGPA  \
# 0              Chef                NaN            5.0   NaN
# 1           Teacher                NaN            4.0   NaN
# 2               NaN                5.0            NaN  8.97
# 3           Teacher                NaN            5.0   NaN
# 4  Business Analyst                NaN            1.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# ...

# %%
data_test.isna().sum()
# Out:
# Gender                                    0
# Age                                       0
# Working Professional or Student           0
# Profession                                0
# Academic Pressure                         0
# Work Pressure                             0
# CGPA                                      0
# Study Satisfaction                        0
# Job Satisfaction                          0
# Sleep Duration                           14
# Dietary Habits                           13
# Degree                                    0
# Have you ever had suicidal thoughts ?     0
# Work/Study Hours                          0
# Financial Stress                          0
# Family History of Mental Illness          0
# dtype: int64

# %% [markdown]
# #Discover Existance Value

# %%
data_train["City"].unique()
# Out:
# array(['Ludhiana', 'Varanasi', 'Visakhapatnam', 'Mumbai', 'Kanpur',
#        'Ahmedabad', 'Thane', 'Nashik', 'Bangalore', 'Patna', 'Rajkot',
#        'Jaipur', 'Pune', 'Lucknow', 'Meerut', 'Agra', 'Surat',
#        'Faridabad', 'Hyderabad', 'Srinagar', 'Ghaziabad', 'Kolkata',
#        'Chennai', 'Kalyan', 'Nagpur', 'Vadodara', 'Vasai-Virar', 'Delhi',
#        'Bhopal', 'Indore', 'Ishanabad', 'Vidhi', 'Ayush', 'Gurgaon',
#        'Krishna', 'Aishwarya', 'Keshav', 'Harsha', 'Nalini', 'Aditya',
#        'Malyansh', 'Raghavendra', 'Saanvi', 'M.Tech', 'Bhavna',
#        'Less Delhi', 'Nandini', 'M.Com', 'Plata', 'Atharv', 'Pratyush',
#        'City', '3.0', 'Less than 5 Kalyan', 'MCA', 'Mira', 'Moreadhyay',
#        'Morena', 'Ishkarsh', 'Kashk', 'Mihir', 'Vidya', 'Tolkata', 'Anvi',
#        'Krinda', 'Ayansh', 'Shrey', 'Ivaan', 'Vaanya', 'Gaurav', 'Harsh',
#        'Reyansh', 'Kashish', 'Kibara', 'Vaishnavi', 'Chhavi', 'Parth',
# ...

# %%
data_train['Profession'].unique()
# Out:
# array(['Chef', 'Teacher', nan, 'Business Analyst', 'Finanancial Analyst',
#        'Chemist', 'Electrician', 'Software Engineer', 'Data Scientist',
#        'Plumber', 'Marketing Manager', 'Accountant', 'Entrepreneur',
#        'HR Manager', 'UX/UI Designer', 'Content Writer',
#        'Educational Consultant', 'Civil Engineer', 'Manager',
#        'Pharmacist', 'Financial Analyst', 'Architect',
#        'Mechanical Engineer', 'Customer Support', 'Consultant', 'Judge',
#        'Researcher', 'Pilot', 'Graphic Designer', 'Travel Consultant',
#        'Digital Marketer', 'Lawyer', 'Research Analyst',
#        'Sales Executive', 'Doctor', 'Unemployed', 'Investment Banker',
#        'Family Consultant', 'B.Com', 'BE', 'Student', 'Yogesh', 'Dev',
#        'MBA', 'LLM', 'BCA', 'Academic', 'Profession', 'FamilyVirar',
#        'City Manager', 'BBA', 'Medical Doctor', 'Working Professional',
#        'MBBS', 'Patna', 'Unveil', 'B.Ed', 'Nagpur', 'Moderate', 'M.Ed',
# ...

# %%
groups = {
    0: ['Civil Engineer', 'Mechanical Engineer', 'Software Engineer', 'Electrician', 'Plumber'],
    1: ['Chemist', 'Data Scientist', 'Researcher', 'Research Analyst', 'Pharmacist', 'Doctor', 'Medical Doctor', 'Analyst'],
    2: ['Business Analyst', 'Finanancial Analyst', 'Marketing Manager', 'Manager', 'Investment Banker', 'City Manager', 'HR Manager'],
    3: ['Teacher', 'Educational Consultant', 'Content Writer', 'Academic'],
    4: ['Graphic Designer', 'UX/UI Designer', 'Digital Marketer'],
    5: ['Consultant', 'Travel Consultant', 'Family Consultant'],
    6: ['Lawyer', 'Judge'],
    7: ['Customer Support', 'Accountant', 'Pilot', 'Chef'],
    8: ['Entrepreneur'],
    9: ['B.Com', 'MBA', 'LLM', 'BCA', 'B.Ed', 'M.Ed', 'PhD', 'MBBS', 'BBA', 'BE'],
    10: ['Unemployed', 'Student', 'Working Professional'],
    11: ['Nagpur', 'Patna', 'Visakhapatnam'],
    12: ['Yogesh', 'Dev', 'Pranav', 'Yuvraj', 'FamilyVirar', 'Profession', 'Family', 'Moderate', 'Unveil', np.NaN],
}

mapping = {value: key for key, values in groups.items() for value in values}
data_train['Profession'] = data_train['Profession'].map(mapping)

# %%
data_test['Profession'] = data_test['Profession'].map(mapping)

# %%
print(data_train["Academic Pressure"].unique())
# Calculate the percentage of NaN values in a column
nan_percentage = data_train['Academic Pressure'].isna().mean() * 100

# Display the result
print(f"Percentage of NaN values in the column: {nan_percentage:.2f}%")
data_train['Academic Pressure'].fillna(0, inplace=True)
# Out:
# [nan  5.  2.  3.  4.  1.]
# Percentage of NaN values in the column: 80.17%
# <ipython-input-219-d47e46c13896>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_train['Academic Pressure'].fillna(0, inplace=True)

# %%
data_test['Academic Pressure'].fillna(0, inplace=True)
# Out:
# <ipython-input-220-5719a202c8e8>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test['Academic Pressure'].fillna(0, inplace=True)

# %%
data_train.fillna(0,inplace=True)
data_test.fillna(0,inplace=True)

# %%
data_train["Dietary Habits"].unique()
# Out:
# array(['Healthy', 'Unhealthy', 'Moderate', 'Yes', 'Pratham', 'BSc',
#        'Gender', '3', 'More Healthy', 'Less than Healthy', 'Mihir', '1.0',
#        'Hormonal', 'Electrician', 0, 'No Healthy', 'Less Healthy',
#        'M.Tech', 'Vegas', 'No', 'Male', 'Indoor', 'Class 12', '2'],
#       dtype=object)

# %%
categories = {
    0: ['Healthy', 'More Healthy', 'Moderate'],
    1: ['Unhealthy', 'No Healthy', 'Less than Healthy', 'Less Healthy'],
    2: ['Yes', 'Pratham', 'BSc', 'Gender', '3', 'Mihir', '1.0', 'Hormonal', 'Electrician', 0,
              'M.Tech', 'Vegas', 'No', 'Male', 'Indoor', 'Class 12', '2']
}
mapping = {value: key for key, values in categories.items() for value in values}
data_train['Dietary Habits'] = data_train['Dietary Habits'].map(mapping)
data_test['Dietary Habits'] = data_test['Dietary Habits'].map(mapping)

# %%
data_train["Sleep Duration"].unique()
# Out:
# array(['More than 8 hours', 'Less than 5 hours', '5-6 hours', '7-8 hours',
#        'Sleep_Duration', '1-2 hours', '6-8 hours', '4-6 hours',
#        '6-7 hours', '10-11 hours', '8-9 hours', '40-45 hours',
#        '9-11 hours', '2-3 hours', '3-4 hours', 'Moderate', '55-66 hours',
#        '4-5 hours', '9-6 hours', '1-3 hours', 'Indore', '45', '1-6 hours',
#        '35-36 hours', '8 hours', 'No', '10-6 hours', 'than 5 hours',
#        '49 hours', 'Unhealthy', 'Work_Study_Hours', '3-6 hours',
#        '45-48 hours', '9-5', 'Pune', '9-5 hours'], dtype=object)

# %%
categories = {
    0: [
        'Less than 5 hours', '1-2 hours', '2-3 hours', '3-4 hours', '4-5 hours', '1-3 hours', 'than 5 hours'
    ],
   1: [
        '5-6 hours', '6-8 hours', '4-6 hours', '6-7 hours', '7-8 hours', '8 hours', '8-9 hours'
    ],
    2: [
        'More than 8 hours', '9-11 hours', '10-11 hours', '9-5 hours', '10-6 hours', '9-6 hours'
    ],
    3: [
        '40-45 hours', '45-48 hours', '49 hours', '55-66 hours', '35-36 hours', 'Work_Study_Hours', '45'
    ],
   4: [
        'Sleep_Duration', 'Moderate', 'Indore', 'Pune', 'No', 'Unhealthy', '9-5'
    ]
}

mapping = {value: key for key, values in categories.items() for value in values}
data_train['Sleep Duration'] = data_train['Sleep Duration'].map(mapping)
data_test['Sleep Duration'] = data_test['Sleep Duration'].map(mapping)

# %%
data_train["Degree"].unique()
# Out:
# array(['BHM', 'LLB', 'B.Pharm', 'BBA', 'MCA', 'MD', 'BSc', 'ME', 'B.Arch',
#        'BCA', 'BE', 'MA', 'B.Ed', 'B.Com', 'MBA', 'M.Com', 'MHM', 'BA',
#        'Class 12', 'M.Tech', 'PhD', 'M.Ed', 'MSc', 'B.Tech', 'LLM',
#        'MBBS', 'M.Pharm', 'UX/UI Designer', 'MPA', 'BH', 'Nalini', 'BEd',
#        'B.Sc', 'Veda', 'Bhopal', 'S.Tech', 'Degree', '20', 'Class 11',
#        'H_Pharm', 'M', 'P.Com', 'BPharm', 'Business Analyst', 'M.Arch',
#        'LL.Com', 'Data Scientist', 'MPharm', 'L.Ed', 'P.Pharm', 'Kalyan',
#        'Unite', 'BArch', 'HR Manager', 'Badhya', 'S.Pharm', 'LLBA',
#        'Vrinda', 'M. Business Analyst', 'Bhavesh', '0', 'LLCom', '29',
#        'MTech', 'Vivaan', 'BPA', 'Plumber', '5.61', 'Brit', 'B.03',
#        'Ritik', '5.56', 'MEd', 'B', 'B BA', '7.06', 'B.B.Arch', 'ACA',
#        'Brithika', 'CGPA', '24', 'M_Tech', 'Pihu', 'BB', 'Jhanvi',
#        'LLTech', 'Aarav', 'Entrepreneur', '8.56', 'LHM', 'Lata', 'S.Arch',
# ...

# %%
categories = {
   0: [
        'BHM', 'BCA', 'BE', 'B.Sc', 'BBA', 'B.Com', 'B.Tech', 'B.Ed', 'B.Arch',
        'MCA', 'MBA', 'M.Tech', 'M.Ed', 'M.Com', 'MSc', 'MD', 'B.Pharm', 'M.Pharm',
        'N.Pharm', 'H_Pharm', 'S.Pharm', 'PhD', 'B.Tech', 'LLM', 'M.Tech', 'LL.Com',
        'BPharm', 'M.Arch', 'M.S', 'M.Ed', 'B.3.79'
    ],
    1: [
        'Data Scientist', 'HR Manager', 'UX/UI Designer', 'Business Analyst',
        'Doctor', 'Entrepreneur', 'Plumber', 'Working Professional'
    ],
    2: [
        'Class 11', 'Class 12'
    ],
    3: [
        'Nalini', 'Bhavesh', 'Pihu', 'Jhanvi', 'Vivaan', 'Mahika', 'Esha', 'Ritik',
        'Mihir', 'Advait', 'Aarav', 'Lata', 'Marsh', 'Navya', 'Mthanya', 'Veda', 'Vrinda'
    ],
    4: [
        '20', '29', '5.61', '5.56', '7.06', '8.56', '0', 'B.03', 'B.3.79', 'CGPA', 'ACA',
        'LHM', 'LCA', 'LLS', 'P.Com', 'LLTech', 'LLBA', 'L.Ed', 'LL B.Ed', 'B.Student',
        'B.A', 'B.Ed', 'S.Arch', 'LLM', 'LL.Com', 'Bhopal', 'Kalyan', 'RCA', 'BPA', 'BSc',
        'B.Arch', 'B.Com'
    ]
}

mapping = {value: key for key, values in categories.items() for value in values}
data_train['Degree'] = data_train['Degree'].map(mapping)
data_test['Degree'] = data_test['Degree'].map(mapping)

# %%
data_train["Degree"].fillna(5,inplace=True)
data_test["Degree"].fillna(5,inplace=True)
# Out:
# <ipython-input-228-33b9db2a4d98>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_train["Degree"].fillna(5,inplace=True)
# <ipython-input-228-33b9db2a4d98>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
categories = {
   'No':0,
    'Yes':1
}

data_train['Have you ever had suicidal thoughts ?'] = data_train['Have you ever had suicidal thoughts ?'].map(categories)
data_test['Have you ever had suicidal thoughts ?'] = data_test['Have you ever had suicidal thoughts ?'].map(categories)
data_train['Family History of Mental Illness'] = data_train['Family History of Mental Illness'].map(categories)
data_test['Family History of Mental Illness'] = data_test['Family History of Mental Illness'].map(categories)

# %%
categories = {
   'Female':0,
    'Male':1
}
data_train['Gender'] = data_train['Gender'].map(categories)
data_test['Gender'] = data_test['Gender'].map(categories)

# %%
categories = {
   'Working Professional':0,
    'Student':1
}
data_train['Working Professional or Student'] = data_train['Working Professional or Student'].map(categories)
data_test['Working Professional or Student'] = data_test['Working Professional or Student'].map(categories)

# %%
data_train["City"].unique()
# Out:
# array(['Ludhiana', 'Varanasi', 'Visakhapatnam', 'Mumbai', 'Kanpur',
#        'Ahmedabad', 'Thane', 'Nashik', 'Bangalore', 'Patna', 'Rajkot',
#        'Jaipur', 'Pune', 'Lucknow', 'Meerut', 'Agra', 'Surat',
#        'Faridabad', 'Hyderabad', 'Srinagar', 'Ghaziabad', 'Kolkata',
#        'Chennai', 'Kalyan', 'Nagpur', 'Vadodara', 'Vasai-Virar', 'Delhi',
#        'Bhopal', 'Indore', 'Ishanabad', 'Vidhi', 'Ayush', 'Gurgaon',
#        'Krishna', 'Aishwarya', 'Keshav', 'Harsha', 'Nalini', 'Aditya',
#        'Malyansh', 'Raghavendra', 'Saanvi', 'M.Tech', 'Bhavna',
#        'Less Delhi', 'Nandini', 'M.Com', 'Plata', 'Atharv', 'Pratyush',
#        'City', '3.0', 'Less than 5 Kalyan', 'MCA', 'Mira', 'Moreadhyay',
#        'Morena', 'Ishkarsh', 'Kashk', 'Mihir', 'Vidya', 'Tolkata', 'Anvi',
#        'Krinda', 'Ayansh', 'Shrey', 'Ivaan', 'Vaanya', 'Gaurav', 'Harsh',
#        'Reyansh', 'Kashish', 'Kibara', 'Vaishnavi', 'Chhavi', 'Parth',
# ...

# %%
data_train = data_train.drop(['id', 'Name','City'], axis=1)
data_test= data_test.drop(['id', 'Name','City'], axis=1)

# %% [markdown]
# # Presenting cleaned Data

# %%
data_train.head(20)
# Out:
#     Gender   Age  Working Professional or Student  Profession  \
# 0        0  49.0                                0         7.0
# 1        1  26.0                                0         3.0
# 2        1  33.0                                1        12.0
# 3        1  22.0                                0         3.0
# 4        0  30.0                                0         2.0
# 5        0  59.0                                0         2.0
# 6        1  47.0                                0         1.0
# 7        1  38.0                                0         3.0
# 8        0  24.0                                1        12.0
# 9        0  42.0                                0         0.0
# 10       1  55.0                                0         0.0
# 11       0  51.0                                0         3.0
# 12       1  39.0                                0         1.0
# 13       0  29.0                                0         7.0
# ...

# %%
data_test.head()
# Out:
#    Gender   Age  Working Professional or Student  Profession  \
# 0       1  53.0                                0         6.0
# 1       0  58.0                                0         3.0
# 2       1  53.0                                0         3.0
# 3       0  23.0                                1        12.0
# 4       1  47.0                                0         3.0
#
#    Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0                0.0            2.0  0.00                 0.0
# 1                0.0            2.0  0.00                 0.0
# 2                0.0            4.0  0.00                 0.0
# 3                5.0            0.0  6.84                 1.0
# 4                0.0            5.0  0.00                 0.0
#
#    Job Satisfaction  Sleep Duration  Dietary Habits  Degree  \
# 0               5.0             0.0             0.0     5.0
# 1               4.0             0.0             0.0     4.0
# ...

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X=data_train.drop('Depression',axis=1)
y=data_train['Depression']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9360341151385928
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
sample_submission = pd.read_csv("sample_submission.csv")
sample_submission
# Out:
#            id  Depression
# 0      140700           0
# 1      140701           0
# 2      140702           0
# 3      140703           0
# 4      140704           0
# ...       ...         ...
# 93795  234495           0
# 93796  234496           0
# 93797  234497           0
# 93798  234498           0
# 93799  234499           0
#
# [93800 rows x 2 columns]

# %%
sample_submission.Depression = np.round(np.mean(y_pred, axis=0))
sample_submission
# Out:
#            id  Depression
# 0      140700         0.0
# 1      140701         0.0
# 2      140702         0.0
# 3      140703         0.0
# 4      140704         0.0
# ...       ...         ...
# 93795  234495         0.0
# 93796  234496         0.0
# 93797  234497         0.0
# 93798  234498         0.0
# 93799  234499         0.0
#
# [93800 rows x 2 columns]

# %%
sample_submission.to_csv("submission.csv", index=False)
